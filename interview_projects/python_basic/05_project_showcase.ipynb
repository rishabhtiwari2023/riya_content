# %% [markdown]
# # Project Showcase — Demo scripts and presentation notes
# Use this notebook to prepare a short demo and practice what Riya will say about each project. For each project: 1) Brief intro 2) Demo run commands 3) Key talking points (what you built, a challenge, and one extension).

# %% [markdown]
# ## 1) Number Guessing Game
# - Demo command: `python interview_projects/number_guessing/number_guessing.py --demo`
# - Talking points: randomness, loops, input handling, adding difficulty levels
# - Interview script: "I built a number guessing game that chooses a secret number and gives hints; to make it better I would add difficulty levels and store high-scores."

# %% [markdown]
# ## 2) Gradebook
# - Demo command: `python interview_projects/gradebook/gradebook.py interview_projects/gradebook/gradebook_sample.csv`
# - Talking points: CSV reading, computing averages and finding top students
# - Interview script: "This project reads a CSV file of marks and computes averages and shows the top student(s). A future improvement is adding more stats and CLI flags."

# %% [markdown]
# ## 3) Text Analyzer
# - Demo command: `python interview_projects/text_analyzer/text_analyzer.py interview_projects/text_analyzer/sample_text.txt`
# - Talking points: word frequency, using `collections.Counter`, basic text processing
# - Interview script: "This reads a text file and finds common words; a natural extension would be to remove stopwords and show a word cloud."

# %% [markdown]
# ## 4) Calculator (Safe Eval)
# - Demo command: `python interview_projects/calculator/calculator.py "2 + 3 * (4 - 1)"`
# - Talking points: why `eval` can be dangerous, using `ast` to parse and evaluate safely, simple expression parsing
# - Interview script: "A small CLI calculator that evaluates arithmetic expressions safely using Python's AST module."
#
# ---
#
# ## Presentation Checklist
# - Open the notebook, run the demo commands, and practice the 1-minute pitch for each project.
# - Show one code snippet and explain it in simple steps: what it does, why it was needed, and one improvement you would add.
